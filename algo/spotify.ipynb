# %%
# import requests

# client_id = '1bf7160dc56446378b569f7a74064a12'
# client_secret = 'b40741c5b40a442881e4845602c76322'

# %%
import requests
import base64
import json

# Replace these with your own Spotify API credentials
CLIENT_ID = '1bf7160dc56446378b569f7a74064a12'
CLIENT_SECRET = 'b40741c5b40a442881e4845602c76322'

def get_access_token(client_id, client_secret):
    auth_string = f"{client_id}:{client_secret}"
    auth_bytes = auth_string.encode('utf-8')
    auth_base64 = str(base64.b64encode(auth_bytes), 'utf-8')
    
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": f"Basic {auth_base64}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    
    response = requests.post(url, headers=headers, data=data)
    json_result = json.loads(response.content)
    return json_result['access_token']

def search_artist_tracks(artist_name, track_name, access_token):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    params = {
        "q": f"artist:{artist_name}, track:{track_name}",
        "type": "track",
        "limit": 50  # Maximum allowed by the API
    }
    
    all_tracks = []
    
    while True:
        response = requests.get(url, headers=headers, params=params)
        
        json_result = json.loads(response.content)
        print(json_result)
        
        if 'tracks' in json_result and 'items' in json_result['tracks']:
            tracks = json_result['tracks']['items']
            all_tracks.extend(tracks)
            
            if json_result['tracks']['next']:
                params['offset'] = json_result['tracks']['offset'] + len(tracks)
            else:
                break
        else:
            break
    
    return all_tracks, json_result

def get_song_url(artist_name, track_name):
    # artist_name = "Justin Timberlake"
    # track_name = "Can't Stop the Feeling!"
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    tracks, json_result = search_artist_tracks(artist_name, track_name, access_token)
    
    return json_result['tracks']['items'][0]['external_urls']['spotify']

def main():
    # artist_name = input("Enter the artist name: ")
    artist_name = "Justin Timberlake"
    track_name = "Can't Stop the Feeling!"
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    tracks, json_result = search_artist_tracks(artist_name, track_name, access_token)
    
    print(f"Found {len(tracks)} tracks for {artist_name}:")
    formatted_json = json.dumps(tracks[0], indent=4)
    print(formatted_json)
    for track in tracks:
        print(f"- {track['name']} (Album: {track['album']['name']})")

    return json_result
    

if __name__ == "__main__":
    json_result = main()
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AJustin+Timberlake%2C+track%3ACan%27t+Stop+the+Feeling%21&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05S6yFOzexsgurWstJlBqK'}, 'href': 'https://api.spotify.com/v1/artists/05S6yFOzexsgurWstJlBqK', 'id': '05S6yFOzexsgurWstJlBqK', 'name': 'Trolls', 'type': 'artist', 'uri': 'spotify:artist:05S6yFOzexsgurWstJlBqK'}], 'available_markets': ['AR', 'AU', 'BE', 'BO', 'BR', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PT', 'SG', 'SK', 'ES', 'SE', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'MC', 'ID', 'JP', 'TH', 'VN', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET'], 'external_urls': {'spotify': 'https://open.spotify.com/album/65ayND23IInUPHJKsaAqe7'}, 'href': 'https://api.spotify.com/v1/albums/65ayND23IInUPHJKsaAqe7', 'id': '65ayND23IInUPHJKsaAqe7', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d965d29d7dcf46ade5a8a7e4', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d965d29d7dcf46ade5a8a7e4', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d965d29d7dcf46ade5a8a7e4', 'width': 64}], 'name': 'TROLLS (Original Motion Picture Soundtrack)', 'release_date': '2016-09-23', 'release_date_precision': 'day', 'total_tracks': 13, 'type': 'album', 'uri': 'spotify:album:65ayND23IInUPHJKsaAqe7'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'}, 'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7', 'id': '31TPClRtHm23RisEBtV3X7', 'name': 'Justin Timberlake', 'type': 'artist', 'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}], 'available_markets': ['AR', 'AU', 'BE', 'BO', 'BR', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PT', 'SG', 'SK', 'ES', 'SE', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'MC', 'ID', 'JP', 'TH', 'VN', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET'], 'disc_number': 1, 'duration_ms': 237546, 'explicit': False, 'external_ids': {'isrc': 'USRC11600876'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/1WkMMavIMc4JZ8cfMmxHkI'}, 'href': 'https://api.spotify.com/v1/tracks/1WkMMavIMc4JZ8cfMmxHkI', 'id': '1WkMMavIMc4JZ8cfMmxHkI', 'is_local': False, 'name': 'CAN\'T STOP THE FEELING! (from DreamWorks Animation\'s "TROLLS")', 'popularity': 72, 'preview_url': 'https://p.scd ...
# Found 9 tracks for Justin Timberlake:
# {
#     "album": {
#         "album_type": "album",
#         "artists": [
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/05S6yFOzexsgurWstJlBqK"
#                 },
#                 "href": "https://api.spotify.com/v1/artists/05S6yFOzexsgurWstJlBqK",
#                 "id": "05S6yFOzexsgurWstJlBqK",
#                 "name": "Trolls",
#                 "type": "artist",
#                 "uri": "spotify:artist:05S6yFOzexsgurWstJlBqK"
#             }
#         ],
#         "available_markets": [
#             "AR",
#             "AU",
#             "BE",
#             "BO",
#             "BR",
#             "CA",
#             "CL",
#             "CO",
#             "CR",
#             "CY",
#             "CZ",
#             "DK",
#             "DO",
#             "EC",
#             "EE",
#             "SV",
#             "FI",
#             "FR",
#             "GR",
#             "GT",
#             "HN",
#             "HK",
#             "HU",
#             "IS",
#             "IE",
#             "IT",
#             "LV",
#             "LT",
#             "LU",
#             "MY",
#             "MT",
#             "MX",
#             "NL",
#             "NZ",
#             "NI",
#             "NO",
#             "PA",
#             "PY",
#             "PE",
#             "PH",
#             "PT",
#             "SG",
#             "SK",
#             "ES",
#             "SE",
#             "TW",
#             "TR",
#             "UY",
#             "US",
#             "GB",
#             "AD",
#             "MC",
#             "ID",
#             "JP",
#             "TH",
#             "VN",
#             "ZA",
#             "SA",
#             "AE",
#             "BH",
#             "QA",
#             "OM",
#             "KW",
#             "EG",
#             "MA",
#             "DZ",
#             "TN",
#             "LB",
#             "JO",
#             "PS",
#             "IN",
#             "BY",
#             "KZ",
#             "MD",
#             "UA",
#             "BD",
#             "PK",
#             "LK",
#             "GH",
#             "KE",
#             "NG",
#             "TZ",
#             "UG",
#             "AG",
#             "AM",
#             "BS",
#             "BB",
#             "BZ",
#             "BT",
#             "BW",
#             "BF",
#             "CV",
#             "CW",
#             "DM",
#             "FJ",
#             "GM",
#             "GE",
#             "GD",
#             "GW",
#             "GY",
#             "HT",
#             "JM",
#             "KI",
#             "LS",
#             "LR",
#             "MW",
#             "MV",
#             "ML",
#             "MH",
#             "FM",
#             "NA",
#             "NR",
#             "NE",
#             "PW",
#             "PG",
#             "PR",
#             "WS",
#             "SM",
#             "ST",
#             "SN",
#             "SC",
#             "SL",
#             "SB",
#             "KN",
#             "LC",
#             "VC",
#             "SR",
#             "TL",
#             "TO",
#             "TT",
#             "TV",
#             "VU",
#             "AZ",
#             "BN",
#             "BI",
#             "KH",
#             "CM",
#             "TD",
#             "KM",
#             "GQ",
#             "SZ",
#             "GA",
#             "GN",
#             "KG",
#             "LA",
#             "MO",
#             "MR",
#             "MN",
#             "NP",
#             "RW",
#             "TG",
#             "UZ",
#             "ZW",
#             "BJ",
#             "MG",
#             "MU",
#             "MZ",
#             "AO",
#             "CI",
#             "DJ",
#             "ZM",
#             "CD",
#             "CG",
#             "IQ",
#             "LY",
#             "TJ",
#             "VE",
#             "ET"
#         ],
#         "external_urls": {
#             "spotify": "https://open.spotify.com/album/65ayND23IInUPHJKsaAqe7"
#         },
#         "href": "https://api.spotify.com/v1/albums/65ayND23IInUPHJKsaAqe7",
#         "id": "65ayND23IInUPHJKsaAqe7",
#         "images": [
#             {
#                 "height": 640,
#                 "url": "https://i.scdn.co/image/ab67616d0000b273d965d29d7dcf46ade5a8a7e4",
#                 "width": 640
#             },
#             {
#                 "height": 300,
#                 "url": "https://i.scdn.co/image/ab67616d00001e02d965d29d7dcf46ade5a8a7e4",
#                 "width": 300
#             },
#             {
#                 "height": 64,
#                 "url": "https://i.scdn.co/image/ab67616d00004851d965d29d7dcf46ade5a8a7e4",
#                 "width": 64
#             }
#         ],
#         "name": "TROLLS (Original Motion Picture Soundtrack)",
#         "release_date": "2016-09-23",
#         "release_date_precision": "day",
#         "total_tracks": 13,
#         "type": "album",
#         "uri": "spotify:album:65ayND23IInUPHJKsaAqe7"
#     },
#     "artists": [
#         {
#             "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7"
#             },
#             "href": "https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7",
#             "id": "31TPClRtHm23RisEBtV3X7",
#             "name": "Justin Timberlake",
#             "type": "artist",
#             "uri": "spotify:artist:31TPClRtHm23RisEBtV3X7"
#         }
#     ],
#     "available_markets": [
#         "AR",
#         "AU",
#         "BE",
#         "BO",
#         "BR",
#         "CA",
#         "CL",
#         "CO",
#         "CR",
#         "CY",
#         "CZ",
#         "DK",
#         "DO",
#         "EC",
#         "EE",
#         "SV",
#         "FI",
#         "FR",
#         "GR",
#         "GT",
#         "HN",
#         "HK",
#         "HU",
#         "IS",
#         "IE",
#         "IT",
#         "LV",
#         "LT",
#         "LU",
#         "MY",
#         "MT",
#         "MX",
#         "NL",
#         "NZ",
#         "NI",
#         "NO",
#         "PA",
#         "PY",
#         "PE",
#         "PH",
#         "PT",
#         "SG",
#         "SK",
#         "ES",
#         "SE",
#         "TW",
#         "TR",
#         "UY",
#         "US",
#         "GB",
#         "AD",
#         "MC",
#         "ID",
#         "JP",
#         "TH",
#         "VN",
#         "ZA",
#         "SA",
#         "AE",
#         "BH",
#         "QA",
#         "OM",
#         "KW",
#         "EG",
#         "MA",
#         "DZ",
#         "TN",
#         "LB",
#         "JO",
#         "PS",
#         "IN",
#         "BY",
#         "KZ",
#         "MD",
#         "UA",
#         "BD",
#         "PK",
#         "LK",
#         "GH",
#         "KE",
#         "NG",
#         "TZ",
#         "UG",
#         "AG",
#         "AM",
#         "BS",
#         "BB",
#         "BZ",
#         "BT",
#         "BW",
#         "BF",
#         "CV",
#         "CW",
#         "DM",
#         "FJ",
#         "GM",
#         "GE",
#         "GD",
#         "GW",
#         "GY",
#         "HT",
#         "JM",
#         "KI",
#         "LS",
#         "LR",
#         "MW",
#         "MV",
#         "ML",
#         "MH",
#         "FM",
#         "NA",
#         "NR",
#         "NE",
#         "PW",
#         "PG",
#         "PR",
#         "WS",
#         "SM",
#         "ST",
#         "SN",
#         "SC",
#         "SL",
#         "SB",
#         "KN",
#         "LC",
#         "VC",
#         "SR",
#         "TL",
#         "TO",
#         "TT",
#         "TV",
#         "VU",
#         "AZ",
#         "BN",
#         "BI",
#         "KH",
#         "CM",
#         "TD",
#         "KM",
#         "GQ",
#         "SZ",
#         "GA",
#         "GN",
#         "KG",
#         "LA",
#         "MO",
#         "MR",
#         "MN",
#         "NP",
#         "RW",
#         "TG",
#         "UZ",
#         "ZW",
#         "BJ",
#         "MG",
#         "MU",
#         "MZ",
#         "AO",
#         "CI",
#         "DJ",
#         "ZM",
#         "CD",
#         "CG",
#         "IQ",
#         "LY",
#         "TJ",
#         "VE",
#         "ET"
#     ],
#     "disc_number": 1,
#     "duration_ms": 237546,
#     "explicit": false,
#     "external_ids": {
#         "isrc": "USRC11600876"
#     },
#     "external_urls": {
#         "spotify": "https://open.spotify.com/track/1WkMMavIMc4JZ8cfMmxHkI"
#     },
#     "href": "https://api.spotify.com/v1/tracks/1WkMMavIMc4JZ8cfMmxHkI",
#     "id": "1WkMMavIMc4JZ8cfMmxHkI",
#     "is_local": false,
#     "name": "CAN'T STOP THE FEELING! (from DreamWorks Animation's \"TROLLS\")",
#     "popularity": 72,
#     "preview_url": "https://p.scdn.co/mp3-preview/8f4eee79e9574c8db62ebbdbbb5f14d6f9ed5fba?cid=1bf7160dc56446378b569f7a74064a12",
#     "track_number": 2,
#     "type": "track",
#     "uri": "spotify:track:1WkMMavIMc4JZ8cfMmxHkI"
# }
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") (Album: TROLLS (Original Motion Picture Soundtrack))
# - CAN'T STOP THE FEELING! - Film Version (Album: TROLLS (Original Motion Picture Soundtrack))
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") (Album: Feel Good Friday)
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") (Album: NOW That's What I Call Music, Vol. 59)
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") (Album: Fin de Año Exitos)
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") (Album: NOW That's What I Call Music! 25th Anniversary Volume 1)
# - Can't Stop the Feeling! (Album: Can't Stop the Feeling!)
# - Can't Stop the Feeling - Acoustic Cover (Album: Music for the Moment: Deep Relax with Classical Ambient)
# - Can't Stop the Feeling! (Album: Can't Stop the Feeling!)

# %%
# json_result.keys()
# Out:
# 'https://open.spotify.com/track/1WkMMavIMc4JZ8cfMmxHkI'
